# %%
# importing the libraries
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
# loading the url inside a list so we can iterate through them.
urls = [
    "https://www.talabat.com/uae/restaurant/621133/ginos-deli-jlt?aid=1308",
    "https://www.talabat.com/uae/restaurant/645430/pasta-della-nona-jlt-jumeirah-lakes-towers?aid=1308",
    "https://www.talabat.com/uae/restaurant/50445/pizzaro-marina-3?aid=1308",
    "https://www.talabat.com/uae/restaurant/605052/the-pasta-guyz-dubai-marina?aid=1308",
    "https://www.talabat.com/uae/restaurant/621796/pizza-di-rocco-jumeirah-lakes-towers--jlt?aid=1308",
    "https://www.talabat.com/uae/restaurant/630107/art-of-dum-discovery-gardens?aid=1308",
    "https://www.talabat.com/uae/restaurant/660056/kings-biryani-jumeirah-lakes-towers--jlt?aid=1308",
    "https://www.talabat.com/uae/restaurant/42486/the-500-calorie-projec-jumeirah-lakes-towers--jlt?aid=1308",
    "https://www.talabat.com/uae/restaurant/679777/koussa-blaban-jumeirah-beach-residence--jbr?aid=1308",
    "https://www.talabat.com/uae/restaurant/673790/1-billion-meals-business-bay?aid=1308"
]
print("Number of links : ", len(urls))

df = pd.DataFrame(list())
df.to_csv('output.csv', index=False)
i = 1

#iterating through urls
for url in urls:
    data = requests.get(url).text
    soup = BeautifulSoup(data, 'lxml')
    
    
    # finding the data under script tag
    s = soup.find('script', id='__NEXT_DATA__')


    # converting the data into json format and loading it into a variable
    data = json.loads(s.text)

    # extracting the details about the restaurant and menu from the data
    reaturant_data = data['props']['pageProps']['initialMenuState']['restaurant']
    menu = data['props']['pageProps']['initialMenuState']['menuData']['items']


    # creating resturant table
    menu_items = []
    for i in menu:
        menu_items.append(i['name'])

    resturnt_detail = {}
    resturnt_detail['resturant_name'] = reaturant_data['name']
    resturnt_detail['resturant_logo'] = reaturant_data['logo']
    resturnt_detail['latitude'] = reaturant_data['latitude']
    resturnt_detail['longitude'] = reaturant_data['longitude']
    resturnt_detail['cuisine_tag'] = reaturant_data['cuisineString']
    resturnt_detail['menu_items'] = (','.join(menu_items))

    # creating pandas df from the dictionary
    rest_details_df = pd.DataFrame(resturnt_detail, index=[0])
    print('Table Number : ', i)
    print(rest_details_df)

    
    # creating menu list
    menu_details = []
    menu_items.append(['item_name', 'item_description', 'item_price', 'item_image'])
    for i in menu:
        menu_details.append([i['name'], i['description'], i['price'], i['image']])

    # creating menu dataframe
    menu_details_df = pd.DataFrame(menu_details, columns=['item_name', 'item_description', 'item_price', 'item_image'])
    print(menu_details_df.head(5))

    # writing dataframes to file
    
    df_list = [rest_details_df, menu_details_df]
    with open('output.csv', 'a') as file:
        for df in df_list:
            df.to_csv(file, index=False)
            file.write('\n')
# Out:
# Number of links :  10
# Table Number :  {'id': 897458976, 'name': 'Fanta (250ml)', 'description': '250ml bottle', 'price': 9, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/709BC7CD76DB80270EB26F0BF793CE18?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/709BC7CD76DB80270EB26F0BF793CE18', 'hasChoices': False, 'sectionName': None, 'sectionId': 9612449, 'originalSection': 'Beverages', 'isItemDiscount': False, 'isWithImage': True}
#   resturant_name                                     resturant_logo  \
# 0    Gino's Deli  https://images.deliveryhero.io/image/talabat/r...
#
#            latitude         longitude                 cuisine_tag  \
# 0  25.0648583638963  55.1383772692595  Sandwiches, Pasta, Italian
#
#                                           menu_items
# 0  Gino's Meal for One,Gino's Meal for 2,Family M...
#                 item_name                                   item_description  \
# 0     Gino's Meal for One  Choice of Panuozzo, Fries, and Soft Drink - AE...
# 1       Gino's Meal for 2  Choice of any 2 Panuozzo, 2 Fries, and 2 Soft ...
# 2  Family Meal (Serves 4)  Any 4 Panuozzo or Pasta, 4 Appetisers, 4 Soft ...
# 3     Appetizer Share Box  Choice of any 3 appetizers - perfect for sharing!
# 4          Any 3 Panuozzo  Choice of any 3 of our famous, authentic, fres...
#
#    item_price                                         item_image
# 0          49  https://images.deliveryhero.io/image/talabat/M...
# 1         109  https://images.deliveryhero.io/image/talabat/M...
# 2         199  https://images.deliveryhero.io/image/talabat/M...
# 3          64  https://images.deliveryhero.io/image/talabat/M...
# 4          99  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 957652635, 'name': 'Sprite (290ml)', 'description': '', 'price': 9, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/61E9855C029D4D5C14B6EACABB7AB352?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/61E9855C029D4D5C14B6EACABB7AB352', 'hasChoices': False, 'sectionName': None, 'sectionId': 10053413, 'originalSection': 'Beverages', 'isItemDiscount': False, 'isWithImage': True}
#       resturant_name                                     resturant_logo  \
# 0  Pasta Della Nonna  https://images.deliveryhero.io/image/talabat/r...
#
#      latitude    longitude            cuisine_tag  \
# 0  25.0651332  55.13827815  Italian, Pasta, Salad
#
#                                           menu_items
# 0  Nonna's Meal for 1,Nonna's Meal for 2,Pasta Pa...
#                           item_name  \
# 0                Nonna's Meal for 1
# 1                Nonna's Meal for 2
# 2  Pasta Party Pack - Any 4 pasta's
# 3            Nonna's Chicken Strips
# 4                Chili Cheese Bites
#
#                                     item_description  item_price  \
# 0           Any Appetiser, Any Pasta, Any Soft Drink          65
# 1  Any 2 Appetisers, any 2 Pasta's and 2 Soft Dri...         125
# 2                 Choose any 4 pastas from our menu!         149
# 3  Tender, crispy and delicious - thats how Mamma...          29
# 4  Breaded, crispy, (slightly) chili cheesy bites...          29
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 941612004, 'name': 'Al Ain Water Large', 'description': '', 'price': 12, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/FED8D82E2217A4D3BE42D1BEBA586259?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/FED8D82E2217A4D3BE42D1BEBA586259', 'hasChoices': False, 'sectionName': None, 'sectionId': 9935088, 'originalSection': 'Beverages', 'isItemDiscount': False, 'isWithImage': True}
#   resturant_name                                     resturant_logo  \
# 0        Pizzaro  https://images.deliveryhero.io/image/talabat/r...
#
#     latitude  longitude            cuisine_tag  \
# 0  25.083309  55.146559  Italian, Pizza, Pasta
#
#                                           menu_items
# 0  Mixed Seafood Pizza BOGO,4 Cheese Pizza BOGO,H...
#                                        item_name  \
# 0                       Mixed Seafood Pizza BOGO
# 1                            4 Cheese Pizza BOGO
# 2                             Hawaiin Pizza BOGO
# 3                      Buratta Cheese Pizza BOGO
# 4  Bufala Cheese with Sundried Tomato Pizza BOGO
#
#                                     item_description  item_price  \
# 0  Pizza sauce, mozzarella fior di latte, basil, ...        61.0
# 1  Pizza sauce, mozzarella fior di latte, smoked ...        56.0
# 2  Mozzarella fior de latte, turkey ham, beef bac...        56.0
# 3  Pizza sauce, mozzarella fior di latte, semi-dr...        59.0
# 4  Pizza sauce, mozzarella fior di latte, buffalo...        59.0
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 940856918, 'name': 'Water (Vegetarian)', 'description': '', 'price': 5, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/1C59F862BB89C29F42397BA4F8834E66?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/1C59F862BB89C29F42397BA4F8834E66', 'hasChoices': False, 'sectionName': None, 'sectionId': 9927959, 'originalSection': 'DRINKS', 'isItemDiscount': False, 'isWithImage': True}
#    resturant_name                                     resturant_logo  \
# 0  The Pasta Guyz  https://images.deliveryhero.io/image/talabat/r...
#
#            latitude         longitude     cuisine_tag  \
# 0  25.0737758910733  55.1322831934299  Italian, Pasta
#
#                                           menu_items
# 0  Cheesy Garlic Bread (Vegetarian),Arancini,Cris...
#                           item_name  \
# 0  Cheesy Garlic Bread (Vegetarian)
# 1                          Arancini
# 2                   Crispy Calamari
# 3           Bruschetta (Vegetarian)
# 4         Caesar Salad (Vegetarian)
#
#                                     item_description  item_price  \
# 0  A full mini French loaf topped with dried oreg...          29
# 1  (7 pieces) Wild mushroom risotto balls with gr...          42
# 2    Fried calamari with tartar sauce & lemon wedge.          39
# 3  Toasted baguette served with fresh tomato basi...          29
# 4  Romaine lettuce, croutons, shaved parmesan wit...          25
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 930001027, 'name': 'San Pellegrino Small (250ml)', 'description': '', 'price': 9, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/197C99AF8783B10F4975A701D5CB78EF?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/197C99AF8783B10F4975A701D5CB78EF', 'hasChoices': False, 'sectionName': None, 'sectionId': 9848818, 'originalSection': 'Water', 'isItemDiscount': False, 'isWithImage': True}
#    resturant_name                                     resturant_logo  \
# 0  Pizza Di Rocco  https://images.deliveryhero.io/image/talabat/r...
#
#      latitude   longitude            cuisine_tag  \
# 0  25.0650915  55.1387907  Pizza, Pasta, Italian
#
#                                           menu_items
# 0  Meal for One,Meal for 2,Appetiser Sharing Box,...
#                item_name                                   item_description  \
# 0           Meal for One                 Any Pizza, Appetiser & Soft Drink!
# 1             Meal for 2  Any 2 Pizzas, Any Appetizer, 2 Soft Drinks. Su...
# 2  Appetiser Sharing Box                        Choice of any 3 Appetisers!
# 3  Appetiser Sharing Box                        Choice of any 3 Appetisers!
# 4            BBQ Brisket  Tomato sauce, fior di latte mozzarella, homema...
#
#    item_price                                         item_image
# 0          65  https://images.deliveryhero.io/image/talabat/M...
# 1          99  https://images.deliveryhero.io/image/talabat/M...
# 2          72  https://images.deliveryhero.io/image/talabat/M...
# 3          72  https://images.deliveryhero.io/image/talabat/M...
# 4          58  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 948172301, 'name': 'MANGO LASSI', 'description': 'lassi', 'price': 16.8, 'oldPrice': -1, 'rating': 0, 'image': None, 'originalImage': None, 'hasChoices': False, 'sectionName': None, 'sectionId': 9984856, 'originalSection': 'COLD BEVERAGES', 'isItemDiscount': False, 'isWithImage': False}
#   resturant_name                                     resturant_logo  \
# 0     ART OF DUM  https://images.deliveryhero.io/image/talabat/r...
#
#      latitude   longitude            cuisine_tag  \
# 0  25.0492932  55.1320226  Indian, Curry, Grills
#
#                                           menu_items
# 0  AWADHI MURGH BIRYANI,FIRANGI CHICKEN TIKKA BIR...
#                        item_name  \
# 0           AWADHI MURGH BIRYANI
# 1  FIRANGI CHICKEN TIKKA BIRYANI
# 2        AWADHI SOYA CHAAAP ROLL
# 3              BHUNA KHEEMA ROLL
# 4                       EGG ROLL
#
#                                     item_description  item_price  \
# 0  A classic Delicacy of the Mughal Nizam, aromat...       60.90
# 1  Char grilled chicken tikka layered along aroma...       60.90
# 2  Creamy Soya chaap spiced with masala and wrapp...       36.75
# 3  Mutton mince flavoured with spices wrapped in ...       44.10
# 4  Egg wrapped in crispy flaky bread along salad ...       34.65
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2                                               None
# 3                                               None
# 4                                               None
# Table Number :  {'id': 725522525, 'name': 'Gulab Jamun & Rabri', 'description': 'Sliced gulab jamun served with rabri.', 'price': 15, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/mmw_637776812122909422?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/mmw_637776812122909422', 'hasChoices': False, 'sectionName': 'Desserts', 'sectionId': 7830350, 'originalSection': 'Desserts', 'isItemDiscount': False, 'isWithImage': True}
#               resturant_name  \
# 0  Kings Biryani & Kebabs Co
#
#                                       resturant_logo          latitude  \
# 0  https://images.deliveryhero.io/image/talabat/r...  25.0688303556849
#
#           longitude                     cuisine_tag  \
# 0  55.1397296122684  Indian, Asian, Biryani, Grills
#
#                                           menu_items
# 0  Bhatti Chicken,Achari Chicken Tikka,Murg Malai...
#                      item_name  \
# 0               Bhatti Chicken
# 1         Achari Chicken Tikka
# 2             Murg Malai Tikka
# 3  Galli Ka Murgh Kebab Skewer
# 4       Hariyali Chicken Kebab
#
#                                     item_description  item_price  \
# 0  Boneless chicken marinated in flavorful mix of...          42
# 1  Chicken cooked to perfection in tandoor with a...          42
# 2  Chicken strips with cream and cheese cooked in...          42
# 3  Minced chicken blended with Kraft cheese cooke...          42
# 4  Chicken chunk marinated with mint, coriander a...          42
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 355703963, 'name': 'Diet Coke 300 ml', 'description': '', 'price': 7, 'oldPrice': -1, 'rating': 5, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/blob_637550461840259511?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/blob_637550461840259511', 'hasChoices': False, 'sectionName': None, 'sectionId': 1139729, 'originalSection': 'Refreshments', 'isItemDiscount': False, 'isWithImage': True}
#             resturant_name                                     resturant_logo  \
# 0  The 500 Calorie Project  https://images.deliveryhero.io/image/talabat/r...
#
#     latitude  longitude             cuisine_tag  \
# 0  25.072739  55.142939  Healthy, Salad, Grills
#
#                                           menu_items
# 0  Grilled Salmon Salad With Cajun Seasoning 482 ...
#                                            item_name  \
# 0  Grilled Salmon Salad With Cajun Seasoning 482 ...
# 1               Citrusy Lemon Chicken Steak 478 Kcal
# 2                 Spicy Garlic Shrimp Salad 374 Kcal
# 3                 Grilled Tender Beef Salad 336 Kcal
# 4             Salmon Teriyaki Grilled Salad 498 Kcal
#
#                                     item_description  item_price  \
# 0  (Carbs: 18 Fats: 31 Protein: 36) Norwegian Caj...          55
# 1  Carbs: 21 Fats: 29 Protein: 35 - Marinated Chi...          39
# 2  Carbs: 18 Fats: 21 Protein: 29 - Cajun Shrimps...          45
# 3  (Carbs: 14 Fats: 18 Protein: 41) Beef Steak (w...          55
# 4  (Carbs: 23 Fats: 31 Protein: 36) Norwegian Sal...          55
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 959679043, 'name': 'Perrier Water', 'description': '200ml', 'price': 12, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/FA1777B2B744A6F21DC14820010BEFF5?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/FA1777B2B744A6F21DC14820010BEFF5', 'hasChoices': False, 'sectionName': None, 'sectionId': 10062943, 'originalSection': 'Fresh Juices & Drinks', 'isItemDiscount': False, 'isWithImage': True}
#   resturant_name                                     resturant_logo  \
# 0  Koussa Blaban  https://images.deliveryhero.io/image/talabat/r...
#
#      latitude   longitude                       cuisine_tag  \
# 0  25.0821019  55.1404354  Middle eastern, Lebanese, Arabic
#
#                                           menu_items
# 0  Greek Salad,Fattoush,Tabbouleh,Hummus,Hummus S...
#                  item_name                                   item_description  \
# 0              Greek Salad  Romaine lettuce, cherry tomatoes, cucumber, re...
# 1                 Fattoush  Lettuce, tomatoes, cucumbers, green peppers, r...
# 2                Tabbouleh  Chopped parsley leaves, tomatoes, onions and b...
# 3                   Hummus  Classic lebanese chickpea puree. Served with a...
# 4  Hummus Shawarma Chicken  Chickpea puree topped with chicken shawarma. S...
#
#    item_price                                         item_image
# 0          24  https://images.deliveryhero.io/image/talabat/M...
# 1          19  https://images.deliveryhero.io/image/talabat/M...
# 2          19  https://images.deliveryhero.io/image/talabat/M...
# 3          17  https://images.deliveryhero.io/image/talabat/M...
# 4          24  https://images.deliveryhero.io/image/talabat/M...
# Table Number :  {'id': 886542029, 'name': '500 Meals', 'description': 'food parcel containing essential food ingredients, such as rice, flour, chickpeas, lentils, sugar, cooking oil, dates and milk- equivalent to500 meals\nThis campaign is licensed by IACAD, permit number 4710', 'price': 500, 'oldPrice': -1, 'rating': 0, 'image': 'https://images.deliveryhero.io/image/talabat/Menuitems/400x300500_meals637844199348284714.png?width=172&amp;height=172', 'originalImage': 'https://images.deliveryhero.io/image/talabat/Menuitems/400x300500_meals637844199348284714.png', 'hasChoices': False, 'sectionName': None, 'sectionId': 9510180, 'originalSection': 'Meals Donations', 'isItemDiscount': False, 'isWithImage': True}
#     resturant_name                                     resturant_logo  \
# 0  1 Billion Meals  https://images.deliveryhero.io/image/talabat/r...
#
#     latitude   longitude       cuisine_tag  \
# 0  24.966473  55.1486314  Charity, Emirati
#
#                                          menu_items
# 0  10 Meals,50 Meals,100 Meals ,300 Meals,500 Meals
#     item_name                                   item_description  item_price  \
# 0    10 Meals  food parcel containing essential food ingredie...          10
# 1    50 Meals  food parcel containing essential food ingredie...          50
# 2  100 Meals   food parcel containing essential food ingredie...         100
# 3   300 Meals  food parcel containing essential food ingredie...         300
# 4   500 Meals  food parcel containing essential food ingredie...         500
#
#                                           item_image
# 0  https://images.deliveryhero.io/image/talabat/M...
# 1  https://images.deliveryhero.io/image/talabat/M...
# 2  https://images.deliveryhero.io/image/talabat/M...
# 3  https://images.deliveryhero.io/image/talabat/M...
# 4  https://images.deliveryhero.io/image/talabat/M...
